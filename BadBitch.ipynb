# %% [markdown]
# <a href="https://colab.research.google.com/github/Mariyaben/Parallel_programming/blob/main/BadBitch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.cluster import KMeans

# Load the Iris dataset
iris = datasets.load_iris()
X = iris.data

kmeans = KMeans(n_clusters=3, random_state=42)
kmeans.fit(X)

centers = kmeans.cluster_centers_
labels = kmeans.labels_

plt.figure(figsize=(8, 6))

plt.scatter(X[:, 0], X[:, 1], c=labels, cmap='viridis', s=50, alpha=0.5, label='Data Points')

plt.scatter(centers[:, 0], centers[:, 1], c='red', s=200, alpha=0.8, label='Cluster Centroids')

plt.title('K-means Clustering on Iris Dataset')
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
# !pip install -U scikit-fuzzy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 994.0/994.0 kB 8.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for scikit-fuzzy: filename=scikit_fuzzy-0.4.2-py3-none-any.whl size=894077 sha256=ace522f5600a1e7f89cdd0cb53276aae6c0a460237df9569fc7e345c1c1903d6
#   Stored in directory: /root/.cache/pip/wheels/4f/86/1b/dfd97134a2c8313e519bcebd95d3fedc7be7944db022094bc8
# Successfully built scikit-fuzzy
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets
import skfuzzy as fuzz

iris = datasets.load_iris()
X = iris.data

cntr, u, u0, d, jm, p, fpc = fuzz.cluster.cmeans(
    X.T, c=3, m=2, error=0.005, maxiter=1000, init=None)

centers = cntr.T

labels = np.argmax(u, axis=0)

plt.figure(figsize=(8, 6))

plt.scatter(X[:, 0], X[:, 1], c=labels, cmap='viridis', s=50, alpha=0.5, label='Data Points')

plt.scatter(centers[:, 0], centers[:, 1], c='red', s=200, alpha=0.8, label='Cluster Centroids')

plt.title('Fuzzy C-means Clustering on Iris Dataset')
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
plt.legend()
plt.show()

# %%
pip install scikit-learn-extra
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 8.1 MB/s eta 0:00:00
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn_extra.cluster import KMedoids

iris = datasets.load_iris()
X = iris.data

kmedoids = KMedoids(n_clusters=3, random_state=0)
kmedoids.fit(X)

labels = kmedoids.labels_
medoids = kmedoids.cluster_centers_

plt.figure(figsize=(8, 6))

plt.scatter(X[:, 0], X[:, 1], c=labels, cmap='viridis', s=50, alpha=0.5, label='Data Points')

plt.scatter(medoids[:, 0], medoids[:, 1], c='red', s=200, alpha=0.8, label='Cluster Medoids')

plt.title('K-medoids Clustering on Iris Dataset')
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
plt.legend()
plt.show()
